# %%
# %load_ext autoreload
# %autoreload 2
from sklearn.svm import SVC
import numpy as np
import matplotlib.pyplot as plt
import os
from quakSpaceTools import evalKernelSVM
from tqdm import tqdm
import h5py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
space="QCDBKG_mjjFlat-XYY_X3000_Y80_UL17-Wp3000_B400_UL17-Qstar2000_W400_UL17-Wkk_W3000_R400_UL17-RSG_M3000_UL17"
reductions=["Sum","Min","inv2norm","inv5norm","inv10norm"]
transforms=['None']
print(f"QUAK Space : {space}")
results = {}
for reduc in reductions:
    for transf in transforms:
        print(f"Running for transform {transf}, reduction {reduc}")
        base = f"quakSpaces/2017/transform-{transf}_reduce-{reduc}/{space}/"
        #signals = [k.split(".")[0] for k in os.listdir(base) if ".npy" in k and "QCDBKG" not in k]
        signals = ["XYY_X3000_Y80_UL17","Wp3000_B400_UL17","Qstar2000_W400_UL17","RSG_M3000_UL17","Wkk_W3000_R400_UL17"]
        accs = {}
        for s in signals:
            print(f"-{s}")
            mean_acc = evalKernelSVM(base,s)
            accs[s] = mean_acc
            print(f"--Acc {mean_acc:.5f}")
        results[f"({transf},{reduc})"] = accs
# Out:
# QUAK Space : QCDBKG_mjjFlat-XYY_X3000_Y80_UL17-Wp3000_B400_UL17-Qstar2000_W400_UL17-Wkk_W3000_R400_UL17-RSG_M3000_UL17
# Running for transform None, reduction Sum
# -XYY_X3000_Y80_UL17
# --Train on 38896 sig events, 38896 bkg events
# --Acc 0.93074
# -Wp3000_B400_UL17
# --Train on 34087 sig events, 34087 bkg events
# --Acc 0.90155
# -Qstar2000_W400_UL17
# --Train on 28722 sig events, 28722 bkg events
# --Acc 0.63682
# -RSG_M3000_UL17
# --Train on 34612 sig events, 34612 bkg events
# --Acc 0.69513
# -Wkk_W3000_R400_UL17
# --Train on 28195 sig events, 28195 bkg events
# --Acc 0.85374
# Running for transform None, reduction Min
# -XYY_X3000_Y80_UL17
# --Train on 38896 sig events, 38896 bkg events
# --Acc 0.89752
# -Wp3000_B400_UL17
# --Train on 34087 sig events, 34087 bkg events
# --Acc 0.91633
# -Qstar2000_W400_UL17
# --Train on 28722 sig events, 28722 bkg events
# --Acc 0.65088
# -RSG_M3000_UL17
# --Train on 34612 sig events, 34612 bkg events
# --Acc 0.73316
# -Wkk_W3000_R400_UL17
# ...

# %% [markdown]
# XYY -- sum 0.93074, min 0.89752, inv2norm 0.92565
# Wpr -- sum 0.90155, min 0.91633, inv2norm 0.91369
# Qstar -- sum 0.63682, min 0.65088, inv2norm 0.64622

# %%
space="QCDBKG_mjjFlat-XYY_X3000_Y80_UL17-and-Wp3000_B400_UL17-and-Qstar2000_W400_UL17"
reductions=["None"]
transforms=['None']
print(f"QUAK Space : {space}")
results = {}
for reduc in reductions:
    for transf in transforms:
        print(f"Running for transform {transf}, reduction {reduc}")
        base = f"quakSpaces/2017/transform-{transf}_reduce-{reduc}/{space}/"
        #signals = [k.split(".")[0] for k in os.listdir(base) if ".npy" in k and "QCDBKG" not in k]
        signals = ["XYY_X3000_Y80_UL17","Wp3000_B400_UL17","Qstar2000_W400_UL17","RSG_M3000_UL17","Wkk_W3000_R400_UL17"]
        accs = {}
        for s in signals:
            print(f"-{s}")
            mean_acc = evalKernelSVM(base,s)
            accs[s] = mean_acc
            print(f"--Acc {mean_acc:.5f}")
        results[f"({transf},{reduc})"] = accs
# Out:
# QUAK Space : QCDBKG_mjjFlat-XYY_X3000_Y80_UL17-and-Wp3000_B400_UL17-and-Qstar2000_W400_UL17
# Running for transform None, reduction None
# -XYY_X3000_Y80_UL17
# --Train on 38896 sig events, 38896 bkg events
# --Acc 0.92688
# -Wp3000_B400_UL17
# --Train on 34087 sig events, 34087 bkg events
# --Acc 0.91217
# -Qstar2000_W400_UL17
# --Train on 28722 sig events, 28722 bkg events
# --Acc 0.66049
# -RSG_M3000_UL17
# --Train on 34612 sig events, 34612 bkg events
# --Acc 0.66335
# -Wkk_W3000_R400_UL17
# --Train on 28195 sig events, 28195 bkg events
# --Acc 0.83125

# %%
space="QCDBKG_mjjFlat-XYY_X3000_Y80_UL17"
reductions=["None"]
transforms=['None']
print(f"QUAK Space : {space}")
results = {}
for reduc in reductions:
    for transf in transforms:
        print(f"Running for transform {transf}, reduction {reduc}")
        base = f"quakSpaces/2017/transform-{transf}_reduce-{reduc}/{space}/"
        #signals = [k.split(".")[0] for k in os.listdir(base) if ".npy" in k and "QCDBKG" not in k]
        signals = ["XYY_X3000_Y80_UL17","Wp3000_B400_UL17","Qstar2000_W400_UL17","RSG_M3000_UL17","Wkk_W3000_R400_UL17"]
        accs = {}
        for s in signals:
            print(f"-{s}")
            mean_acc = evalKernelSVM(base,s)
            accs[s] = mean_acc
            print(f"--Acc {mean_acc:.5f}")
        results[f"({transf},{reduc})"] = accs
# Out:
# (4862, 4)

# %%
fb = np.load("quakSpaces/2017/transform-None_reduce-inv5norm/QCDBKG_mjjFlat-XYY_X3000_Y80_UL17-Wp3000_B400_UL17-Qstar2000_W400_UL17-Wkk_W3000_R400_UL17-RSG_M3000_UL17/QCDBKG.npy")
fx = np.load("quakSpaces/2017/transform-None_reduce-inv5norm/QCDBKG_mjjFlat-XYY_X3000_Y80_UL17-Wp3000_B400_UL17-Qstar2000_W400_UL17-Wkk_W3000_R400_UL17-RSG_M3000_UL17/XYY_X3000_Y80_UL17.npy")
fw = np.load("quakSpaces/2017/transform-None_reduce-inv5norm/QCDBKG_mjjFlat-XYY_X3000_Y80_UL17-Wp3000_B400_UL17-Qstar2000_W400_UL17-Wkk_W3000_R400_UL17-RSG_M3000_UL17/Wkk_W3000_R400_UL17.npy")

# %%
plt.hist(fw[:,2],histtype='step',bins=100)
#plt.hist(fb[:,2],histtype='step')
#plt.hist(fx[:,2],histtype='step')
plt.yscale('log')
plt.grid()

# %%
fb = h5py.File("lossEvaluations/2017/QCDBKG.h5")
fx = h5py.File("lossEvaluations/2017/XYY_X3000_Y80_UL17.h5")
fw = h5py.File("lossEvaluations/2017/Wkk_W3000_R400_UL17.h5")
print(fb.keys())
# Out:
# <KeysViewHDF5 ['QCDBKG_mjjFlat', 'Qstar2000_W400_UL17', 'RSG_M3000_UL17', 'Wkk_W3000_R400_UL17', 'Wp3000_B400_UL17', 'XYY_X3000_Y80_UL17', 'XYY_X3000_Y80_UL17-and-Wp3000_B400_UL17-and-Qstar2000_W400_UL17', 'dEta', 'fname', 'mjj']>

# %%
loss = "QCDBKG_mjjFlat"
lb = fb[loss][()]
lx = fx[loss][()]
lw = fw[loss][()]
plt.figure(figsize=(8,6))
hb = plt.hist(lb,histtype='step',density=True,bins=100)
hx = plt.hist(lx,histtype='step',density=True,bins=100)
hw = plt.hist(lw,histtype='step',density=True,bins=100)
plt.yscale('log')

# %%
t1 = np.random.exponential(scale=5,size=10000)
t2 = np.random.exponential(scale=20,size=10000)
plt.figure(figsize=(16,6))
plt.subplot(121)
h1 = plt.hist(t1,bins=np.linspace(0,200,100),histtype='step')
h2 = plt.hist(t2,bins=np.linspace(0,200,100),histtype='step')
plt.yscale('log')
plt.subplot(122)
n1 = (t1-t1.mean())/t1.std()
n2 = (t2-t1.mean())/t1.std()
h1 = plt.hist(n1,bins=np.linspace(0,100,100),histtype='step')
h2 = plt.hist(n2,bins=np.linspace(0,100,100),histtype='step')
plt.yscale('log')

# %%
t1 = np.log(np.random.exponential(scale=5,size=10000))
t2 = np.log(np.random.exponential(scale=20,size=10000))
plt.figure(figsize=(16,6))
plt.subplot(121)
h1 = plt.hist(t1,bins=np.linspace(-10,10,100),histtype='step')
h2 = plt.hist(t2,bins=np.linspace(-10,10,100),histtype='step')
plt.yscale('log')
plt.subplot(122)
n1 = (t1-t1.mean())/t1.std()
n2 = (t2-t1.mean())/t1.std()
h1 = plt.hist(n1,bins=np.linspace(-10,10,100),histtype='step')
h2 = plt.hist(n2,bins=np.linspace(-10,10,100),histtype='step')
plt.yscale('log')

# %%
fb = h5py.File("input_h5s/bkg_BB_UL17/bkg_UL17.h5")
fx = h5py.File("input_h5s/signal_UL17/XYY_X3000_Y80_UL17/XYY_X3000_Y80_UL17.h5")
fw = h5py.File("input_h5s/signal_UL17/Wp3000_B400_UL17/Wp3000_B400_UL17.h5")

# %%
v = "jet1_rho"
rb = fb[v][()]
rx = fx[v][()]
rw = fw[v][()]
m = rb.mean()
sd = rb.std()
rb=(rb-m)/sd
rx=(rx-m)/sd
rw=(rw-m)/sd
plt.figure(figsize=(8,6))
hb = plt.hist(rb,histtype='step',density=True,bins=100)
hx = plt.hist(rx,histtype='step',density=True,bins=100)
hw = plt.hist(rw,histtype='step',density=True,bins=100)
plt.yscale('log')

# %%
v = "jet1_mass"
rb = fb[v][()]
rx = fx[v][()]
rw = fw[v][()]
#m = rb.mean()
#sd = rb.std()
#rb=(rb-m)/sd
#rx=(rx-m)/sd
#rw=(rw-m)/sd
plt.figure(figsize=(8,6))
hb = plt.hist(rb,histtype='step',density=True,bins=100)
hx = plt.hist(rx,histtype='step',density=True,bins=100)
hw = plt.hist(rw,histtype='step',density=True,bins=100)
plt.yscale('log')

# %%
np.log((rx+10)).min()
# Out:
# 2.3025882

# %%
v = "jet1_mass"
rb = fb[v][()]
rx = fx[v][()]
rw = fw[v][()]
rb = np.log(2+rb)
rx = np.log(2+rx)
rw = np.log(2+rw)
m = rb.mean()
sd = rb.std()
rb=(rb-m)/sd
rx=(rx-m)/sd
rw=(rw-m)/sd
plt.figure(figsize=(8,6))
hb = plt.hist(rb,histtype='step',density=True,bins=100)
hx = plt.hist(rx,histtype='step',density=True,bins=100)
hw = plt.hist(rw,histtype='step',density=True,bins=100)
plt.yscale('log')

# %%
v = "jet1_tauS"
rb = np.log(1+fb[v][()])
rx = np.log(1+fx[v][()])
rw = np.log(1+fw[v][()])
m = rb.mean()
sd = rb.std()
rb=(rb-m)/sd
rx=(rx-m)/sd
rw=(rw-m)/sd
plt.figure(figsize=(8,6))
hb = plt.hist(rb,histtype='step',density=True,bins=100)
hx = plt.hist(rx,histtype='step',density=True,bins=100)
hw = plt.hist(rw,histtype='step',density=True,bins=100)
plt.yscale('log')

# %%
v = "jet2_tauS"
rb = np.log(1+fb[v][()])
rx = np.log(1+fx[v][()])
rw = np.log(1+fw[v][()])
m = rb.mean()
sd = rb.std()
rb=(rb-m)/sd
rx=(rx-m)/sd
rw=(rw-m)/sd
plt.figure(figsize=(8,6))
hb = plt.hist(rb,histtype='step',density=True,bins=100)
hx = plt.hist(rx,histtype='step',density=True,bins=100)
hw = plt.hist(rw,histtype='step',density=True,bins=100)
plt.yscale('log')

# %%
v = "jet1_pb"
rb = fb[v][()]
rx = fx[v][()]
rw = fw[v][()]
m = rb.mean()
sd = rb.std()
rb=(rb-m)/sd
rx=(rx-m)/sd
rw=(rw-m)/sd
plt.figure(figsize=(8,6))
hb = plt.hist(rb,histtype='step',density=True,bins=100)
hx = plt.hist(rx,histtype='step',density=True,bins=100)
hw = plt.hist(rw,histtype='step',density=True,bins=100)
plt.yscale('log')

# %%
v = "jet1_pb"
rb = fb[v][()]
rb=rb[rb>0]
rx = fx[v][()]
rx=rx[rx>0]
rw = fw[v][()]
rw=rw[rw>0]

#rb=np.log(1+100*rb)
#rx=np.log(1+100*rx)
#rw=np.log(1+100*rw)
#m = rb.mean()
#sd = rb.std()
#rb=(rb-m)/sd
#rx=(rx-m)/sd
#rw=(rw-m)/sd
plt.figure(figsize=(8,6))
hb = plt.hist(rb,histtype='step',density=True,bins=100)
hx = plt.hist(rx,histtype='step',density=True,bins=100)
hw = plt.hist(rw,histtype='step',density=True,bins=100)
plt.yscale('log')

# %%
v = "jet1_pb"
rb = fb[v][()]
rb[rb<0]=0
rx = fx[v][()]
rx[rx<0]=0
rw = fw[v][()]
rw[rw<0]=0

#rb=np.log(10+100*rb)
#rx=np.log(10+100*rx)
#rw=np.log(10+100*rw)
m = rb.mean()
sd = rb.std()
rb=(rb-m)/sd
rx=(rx-m)/sd
rw=(rw-m)/sd
plt.figure(figsize=(8,6))
hb = plt.hist(rb,histtype='step',density=True,bins=100)
hx = plt.hist(rx,histtype='step',density=True,bins=100)
hw = plt.hist(rw,histtype='step',density=True,bins=100)
#plt.yscale('log')
