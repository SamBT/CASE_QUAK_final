# %%
# %load_ext autoreload
# %autoreload 2
from quakSpaceTools import QuakSpaceMaker, LossEval, LossTransform
import numpy as np
import matplotlib.pyplot as plt
import h5py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Evaluating Losses

# %%
mean_reference = "BKG"
lossEval = LossEval(mean_reference=mean_reference,overwrite=True)
# Out:
# extras =  []

# %%
# Evaluate on background samples
lossEval.evaluateLosses("BKG",chunkSize=100000)
# Out:
# writing mass & systematics
# ...
# 100%|██████████| 25/25 [00:16<00:00,  1.50it/s]

# %%
# Evaluate on signal samples
lossEval.evaluateLosses("SIG",chunkSize=100000)
# Out:
# writing mass & systematics
# ...
# 100%|██████████| 25/25 [02:35<00:00,  6.24s/it]

# %%
# Evaluate on data sideband
lossEval.evaluateLosses("DATA_SB",chunkSize=100000)
# Out:
# writing mass & systematics
# ...
# 100%|██████████| 25/25 [00:31<00:00,  1.27s/it]

# %%
# Evaluate on bkg sideband
lossEval.evaluateLosses("BKG_SB",chunkSize=100000)
# Out:
# writing mass & systematics
# ...
# 100%|██████████| 25/25 [00:08<00:00,  2.84it/s]

# %% [markdown]
# # Evaluate losses on new trainings

# %%
mean_reference = "BKG"
lossEval = LossEval(mean_reference=mean_reference,overwrite=False)
# Out:
# extras =  []

# %%
# Evaluate on background samples
lossEval.evaluateLosses("BKG",chunkSize=100000)
# Out:
# ...
# 100%|██████████| 5/5 [00:02<00:00,  1.71it/s]

# %%
# Evaluate on signal samples
lossEval.evaluateLosses("SIG",chunkSize=100000)
# Out:
# ...
# 100%|██████████| 5/5 [00:28<00:00,  5.75s/it]

# %% [markdown]
# # Various Loss Normalizations

# %%
from quakSpaceTools import normalizeLosses

# %%
normalizeLosses("pca",doBoxCox=True)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 25/25 [00:32<00:00,  1.29s/it]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:19<28:33, 19.25s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:21<13:08,  8.96s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:21<07:37,  5.26s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:23<05:19,  3.71s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:24<03:50,  2.71s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:25<02:57,  2.11s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:26<02:30,  1.81s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:27<02:03,  1.51s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:28<01:54,  1.41s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:29<01:47,  1.35s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("linear",doBoxCox=True)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 25/25 [00:10<00:00,  2.45it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:17<26:15, 17.70s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:18<11:48,  8.05s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:19<06:52,  4.75s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:20<04:45,  3.31s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:21<03:23,  2.39s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:22<02:33,  1.83s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:23<02:06,  1.52s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:24<01:43,  1.26s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:25<01:35,  1.18s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:25<01:29,  1.12s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("pca",doBoxCox=False)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 25/25 [00:18<00:00,  1.35it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:19<29:28, 19.87s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:21<13:23,  9.13s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:22<07:43,  5.33s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:23<05:21,  3.74s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:24<03:48,  2.69s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:25<02:53,  2.07s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:28<03:30,  2.53s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:29<02:40,  1.96s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:35<04:09,  3.08s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:36<03:22,  2.54s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("linear",doBoxCox=False)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 25/25 [00:12<00:00,  2.03it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:20<30:56, 20.86s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:22<13:52,  9.46s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:23<08:03,  5.56s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:24<05:29,  3.84s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:25<03:52,  2.74s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:26<02:55,  2.09s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:27<02:24,  1.74s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:27<01:56,  1.42s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:28<01:44,  1.29s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:29<01:38,  1.23s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("none",doBoxCox=False)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:16<24:52, 16.77s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:17<10:53,  7.43s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:18<06:12,  4.28s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:18<04:08,  2.89s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:19<02:54,  2.06s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:20<02:11,  1.56s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:20<01:47,  1.29s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:21<01:25,  1.05s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:22<01:18,  1.03it/s]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:22<01:13,  1.09it/s]
# lossEvals/XYY5000_Y80_Yp80.h5
#  12%|█▏        | 11/90 [00:23<01:09,  1.14it/s]
# lossEvals/XYY3000_Y25_Yp400.h5
# ...
