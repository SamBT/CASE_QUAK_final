# %%
# %load_ext autoreload
# %autoreload 2
from quakSpaceMaker import QuakSpaceMaker
import numpy as np
import matplotlib.pyplot as plt
import h5py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bkg_axis = "BKG_mjjFlat"
sig_axes = ["XYY3000_Y170_Yp170"]

# %%
toInject = "XYY3000_Y170_Yp170"
xs_inject = 50
maker = QuakSpaceMaker(bkg_axis,sig_axes,toInject,xs_inject=50)
maker.run()
# Out:
# Injecting 1002 events / 50.00 fb
# Bkg axis : BKG_mjjFlat
# Sig axes : ['XYY3000_Y170_Yp170']
# Sig Reduction : None
# Mjj decorrelation : linear

# %%
# !python runQuakSpace.py -b BKG_mjjFlat -s XYY3000_Y170_Yp170 -i XYY3000_Y170_Yp170 -x 50
# Out:
# Injecting 50.0 fb / [1002, 1002, 1002, 1002, 1002, 1002, 1002, 1002, 1002] events
# Bkg axis : BKG_mjjFlat
# Sig axes : ['XYY3000_Y170_Yp170']
# Sig Reduction : None
# Mjj decorrelation : linear
# Output at injectedQuakSpaces/transform-None_reduce-None/BKG_mjjFlat-XYY3000_Y170_Yp170/inject-XYY3000_Y170_Yp170_xs50.00.h5
