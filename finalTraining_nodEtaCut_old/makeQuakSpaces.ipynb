# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("/home/sambt/CASE_final/CASE_QUAK_final/commonTools/")
from quakSpaceTools import QuakSpaceMaker, LossEval, LossTransform
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
from samples import signal_map, signal_merged_dir
files = []
fnames = []
for s in signal_map.keys():
    if "RSG" in s:
        continue
    files.append(signal_merged_dir+signal_map[s])
    fnames.append(s)

# %%
fnames[:5]
# Out:
# ['Qstar2000_W170',
#  'Qstar2000_W25',
#  'Qstar2000_W400',
#  'Qstar2000_W80',
#  'Qstar3000_W170']

# %%
a = [True,False,True]
np.any(a)
# Out:
# True

# %%
toEval = ['M80-80', 'M80-170', 'M80-400', 'M170-170', 'M170-400', 'M400-400']
toEval = [f"{s}_sigRemoved" for s in toEval]
for fn in fnames:
    with h5py.File(f"lossEvals/{fn}.h5","r+") as f:
        a = f['mjj'].shape[0]
        #print(fn,a)
        for t in list(f.keys()):
            if 'lund' not in t and np.any([k in t for k in toEval]):
                if f[t].shape[0] != a:
                    arr = f[t][()][:a]
                    del f[t]
                    f.create_dataset(t,data=arr)
                    print(fn,t,f"{f[t].shape[0]} vs {a}")
# Out:
# Qstar2000_W170 M170-170_sigRemoved_JER_down 56568 vs 56568
# Qstar2000_W170 M170-170_sigRemoved_JER_up 56568 vs 56568
# Qstar2000_W170 M170-170_sigRemoved_JES_down 56568 vs 56568
# Qstar2000_W170 M170-170_sigRemoved_JES_up 56568 vs 56568
# Qstar2000_W170 M170-170_sigRemoved_JMR_down 56568 vs 56568
# Qstar2000_W170 M170-170_sigRemoved_JMR_up 56568 vs 56568
# Qstar2000_W170 M170-170_sigRemoved_JMS_down 56568 vs 56568
# Qstar2000_W170 M170-170_sigRemoved_JMS_up 56568 vs 56568
# Qstar2000_W170 M170-400_sigRemoved_JER_down 56568 vs 56568
# Qstar2000_W170 M170-400_sigRemoved_JER_up 56568 vs 56568
# Qstar2000_W170 M170-400_sigRemoved_JES_down 56568 vs 56568
# Qstar2000_W170 M170-400_sigRemoved_JES_up 56568 vs 56568
# Qstar2000_W170 M170-400_sigRemoved_JMR_down 56568 vs 56568
# Qstar2000_W170 M170-400_sigRemoved_JMR_up 56568 vs 56568
# Qstar2000_W170 M170-400_sigRemoved_JMS_down 56568 vs 56568
# Qstar2000_W170 M170-400_sigRemoved_JMS_up 56568 vs 56568
# ...

# %% [markdown]
# # Evaluating Losses

# %%
mean_reference = "BKG"
lossEval = LossEval(mean_reference=mean_reference,overwrite=True)
# Out:
# extras =  []

# %%
# Evaluate on background samples
lossEval.evaluateLosses("BKG",chunkSize=200000)
# Out:
# writing mass & systematics
# 100%|██████████| 80/80 [00:23<00:00,  3.39it/s]
# file 1/80
# 100%|██████████| 27/27 [00:30<00:00,  1.12s/it]
# file 2/80
# 100%|██████████| 27/27 [00:16<00:00,  1.60it/s]
# file 3/80
# 100%|██████████| 27/27 [00:16<00:00,  1.64it/s]
# file 4/80
# 100%|██████████| 27/27 [00:16<00:00,  1.63it/s]
# file 5/80
# 100%|██████████| 27/27 [00:16<00:00,  1.62it/s]
# file 6/80
# 100%|██████████| 27/27 [00:16<00:00,  1.62it/s]
# file 7/80
# 100%|██████████| 27/27 [00:16<00:00,  1.63it/s]
# file 8/80
# 100%|██████████| 27/27 [00:16<00:00,  1.63it/s]
# file 9/80
# 100%|██████████| 27/27 [00:16<00:00,  1.65it/s]
# file 10/80
# 100%|██████████| 27/27 [00:16<00:00,  1.63it/s]
# file 11/80
# 100%|██████████| 27/27 [00:16<00:00,  1.64it/s]
# file 12/80
# 100%|██████████| 27/27 [00:16<00:00,  1.64it/s]
# file 13/80
# 100%|██████████| 27/27 [00:16<00:00,  1.65it/s]
# file 14/80
# 100%|██████████| 27/27 [00:16<00:00,  1.63it/s]
# file 15/80
# ...

# %%
# Evaluate on signal samples
lossEval.evaluateLosses("SIG",chunkSize=200000)
# Out:
# writing mass & systematics
# 100%|██████████| 83/83 [03:02<00:00,  2.20s/it]
# file 1/83
# 100%|██████████| 27/27 [01:31<00:00,  3.38s/it]
# file 2/83
# 100%|██████████| 27/27 [01:19<00:00,  2.96s/it]
# file 3/83
# 100%|██████████| 27/27 [01:19<00:00,  2.95s/it]
# file 4/83
# 100%|██████████| 27/27 [01:21<00:00,  3.03s/it]
# file 5/83
# 100%|██████████| 27/27 [01:26<00:00,  3.19s/it]
# file 6/83
# 100%|██████████| 27/27 [01:25<00:00,  3.16s/it]
# file 7/83
# 100%|██████████| 27/27 [01:25<00:00,  3.15s/it]
# file 8/83
# 100%|██████████| 27/27 [01:24<00:00,  3.15s/it]
# file 9/83
# 100%|██████████| 27/27 [01:26<00:00,  3.20s/it]
# file 10/83
# 100%|██████████| 27/27 [01:26<00:00,  3.19s/it]
# file 11/83
# 100%|██████████| 27/27 [01:26<00:00,  3.19s/it]
# file 12/83
# 100%|██████████| 27/27 [01:26<00:00,  3.20s/it]
# file 13/83
# 100%|██████████| 27/27 [01:01<00:00,  2.28s/it]
# file 14/83
# 100%|██████████| 27/27 [00:58<00:00,  2.15s/it]
# file 15/83
# ...

# %%
# Evaluate on data SB
lossEval.evaluateLosses("DATA_SB",chunkSize=100000)
# Out:
# writing mass & systematics
# ...
# 100%|██████████| 24/24 [00:26<00:00,  1.12s/it]

# %%
# Evaluate on bkg SB
lossEval.evaluateLosses("BKG_SB",chunkSize=100000)
# Out:
# writing mass & systematics
# ...
# 100%|██████████| 24/24 [00:08<00:00,  2.98it/s]

# %%
# Evaluate on DATA!!!!!
lossEval.evaluateLosses("DATA",chunkSize=100000)
# Out:
# writing mass & systematics
# 100%|██████████| 40/40 [01:08<00:00,  1.71s/it]
# file 1/40
# 100%|██████████| 27/27 [02:06<00:00,  4.69s/it]
# file 2/40
# 100%|██████████| 27/27 [01:58<00:00,  4.38s/it]
# file 3/40
# 100%|██████████| 27/27 [01:57<00:00,  4.34s/it]
# file 4/40
# 100%|██████████| 27/27 [01:57<00:00,  4.35s/it]
# file 5/40
# 100%|██████████| 27/27 [01:54<00:00,  4.26s/it]
# file 6/40
# 100%|██████████| 27/27 [01:53<00:00,  4.20s/it]
# file 7/40
# 100%|██████████| 27/27 [01:52<00:00,  4.18s/it]
# file 8/40
# 100%|██████████| 27/27 [01:51<00:00,  4.13s/it]
# file 9/40
# 100%|██████████| 27/27 [01:51<00:00,  4.13s/it]
# file 10/40
# 100%|██████████| 27/27 [01:50<00:00,  4.11s/it]
# file 11/40
# 100%|██████████| 27/27 [01:50<00:00,  4.10s/it]
# file 12/40
# 100%|██████████| 27/27 [01:50<00:00,  4.11s/it]
# file 13/40
# 100%|██████████| 27/27 [01:51<00:00,  4.12s/it]
# file 14/40
# 100%|██████████| 27/27 [01:50<00:00,  4.10s/it]
# file 15/40
# ...

# %% [markdown]
# # Eval on additional signals

# %%
mean_reference = "BKG"
lossEval = LossEval(mean_reference=mean_reference,overwrite=True)
# Out:
# extras =  []

# %%
signals = ["XYY3000_Y400_Yp400_smear5","XYY3000_Y400_Yp400_smear10","XYY3000_Y400_Yp400_smear20",
           "XYY3000_Y400_Yp400_smear30","XYY3000_Y400_Yp400_smear40"]
lossEval.evaluateLosses(signals,chunkSize=100000)
# Out:
# writing mass & systematics
# 100%|██████████| 5/5 [00:13<00:00,  2.65s/it]
# file 1/5
# 100%|██████████| 27/27 [02:12<00:00,  4.91s/it]
# file 2/5
# 100%|██████████| 27/27 [01:50<00:00,  4.09s/it]
# file 3/5
# 100%|██████████| 27/27 [01:50<00:00,  4.09s/it]
# file 4/5
# 100%|██████████| 27/27 [01:50<00:00,  4.09s/it]
# file 5/5
# 100%|██████████| 27/27 [01:57<00:00,  4.36s/it]

# %% [markdown]
# # Evaluate losses on new trainings

# %%
mean_reference = "BKG"
lossEval = LossEval(mean_reference=mean_reference,overwrite=False)
# Out:
# extras =  []

# %%
# Evaluate on background samples
lossEval.evaluateLosses("BKG",chunkSize=100000)
# Out:
# file 1/80
# 100%|██████████| 71/71 [00:15<00:00,  4.59it/s]
# file 2/80
# 100%|██████████| 71/71 [00:12<00:00,  5.79it/s]
# file 3/80
# 100%|██████████| 71/71 [00:11<00:00,  6.08it/s]
# file 4/80
# 100%|██████████| 71/71 [00:11<00:00,  6.03it/s]
# file 5/80
# 100%|██████████| 71/71 [00:11<00:00,  5.97it/s]
# file 6/80
# 100%|██████████| 71/71 [00:12<00:00,  5.85it/s]
# file 7/80
# 100%|██████████| 71/71 [00:11<00:00,  5.97it/s]
# file 8/80
# 100%|██████████| 71/71 [00:11<00:00,  6.01it/s]
# file 9/80
# 100%|██████████| 71/71 [00:11<00:00,  6.04it/s]
# file 10/80
# 100%|██████████| 71/71 [00:11<00:00,  5.95it/s]
# file 11/80
# 100%|██████████| 71/71 [00:11<00:00,  6.13it/s]
# file 12/80
# 100%|██████████| 71/71 [00:11<00:00,  5.93it/s]
# file 13/80
# 100%|██████████| 71/71 [00:11<00:00,  6.06it/s]
# file 14/80
# 100%|██████████| 71/71 [00:11<00:00,  6.10it/s]
# file 15/80
# 100%|██████████| 71/71 [00:12<00:00,  5.84it/s]
# file 16/80
# 100%|██████████| 71/71 [00:11<00:00,  5.94it/s]
# ...

# %%
# Evaluate on sign al samples
lossEval.evaluateLosses("SIG",chunkSize=100000)
# Out:
# file 1/89
# 100%|██████████| 71/71 [00:55<00:00,  1.27it/s]
# file 2/89
# 100%|██████████| 71/71 [00:55<00:00,  1.27it/s]
# file 3/89
# 100%|██████████| 71/71 [00:56<00:00,  1.26it/s]
# file 4/89
# 100%|██████████| 71/71 [00:55<00:00,  1.27it/s]
# file 5/89
# 100%|██████████| 71/71 [00:58<00:00,  1.20it/s]
# file 6/89
# 100%|██████████| 71/71 [00:58<00:00,  1.20it/s]
# file 7/89
# 100%|██████████| 71/71 [00:59<00:00,  1.19it/s]
# file 8/89
# 100%|██████████| 71/71 [00:58<00:00,  1.22it/s]
# file 9/89
# 100%|██████████| 71/71 [01:00<00:00,  1.17it/s]
# file 10/89
# 100%|██████████| 71/71 [01:00<00:00,  1.18it/s]
# file 11/89
# 100%|██████████| 71/71 [01:00<00:00,  1.17it/s]
# file 12/89
# 100%|██████████| 71/71 [01:00<00:00,  1.17it/s]
# file 13/89
# 100%|██████████| 71/71 [00:45<00:00,  1.55it/s]
# file 14/89
# 100%|██████████| 71/71 [00:43<00:00,  1.62it/s]
# file 15/89
# 100%|██████████| 71/71 [00:48<00:00,  1.46it/s]
# file 16/89
# 100%|██████████| 71/71 [00:47<00:00,  1.48it/s]
# ...

# %%
samples = ['ZTT3000_Tp400','ZTT5000_Tp400','XYY3000_Y400_Yp400_smear5',
           'XYY3000_Y400_Yp400_smear10','XYY3000_Y400_Yp400_smear20','XYY3000_Y400_Yp400_smear30',
          'XYY3000_Y400_Yp400_smear40']
lossEval.evaluateLosses(samples,chunkSize=100000)
# Out:
# file 1/7
# 100%|██████████| 71/71 [01:48<00:00,  1.53s/it]
# file 2/7
# 100%|██████████| 71/71 [01:41<00:00,  1.43s/it]
# file 3/7
# 100%|██████████| 71/71 [01:16<00:00,  1.08s/it]
# file 4/7
# 100%|██████████| 71/71 [01:16<00:00,  1.08s/it]
# file 5/7
# 100%|██████████| 71/71 [01:16<00:00,  1.08s/it]
# file 6/7
# 100%|██████████| 71/71 [01:17<00:00,  1.09s/it]
# file 7/7
# 100%|██████████| 71/71 [01:17<00:00,  1.09s/it]

# %%
# Evaluate on sign al samples
models = [
    "XYY3000_Y170_Yp25",
    "XYY3000_Y25_Yp25",
    "XYY3000_Y25_Yp400",
    "XYY3000_Y25_Yp80",
    "XYY3000_Y400_Yp170",
    "XYY3000_Y400_Yp25",
    "XYY3000_Y80_Yp25",
    "XYY3000_Y80_Yp400",
    "XYY3000_Y170_Yp400",
    "XYY3000_Y170_Yp80",
    "XYY3000_Y25_Yp170",
    "XYY3000_Y400_Yp80",
    "XYY3000_Y80_Yp170",
    "XYY3000_Y80_Yp80",
    "XYY2000_Y170_Yp400",
    "XYY2000_Y25_Yp25",
    "XYY2000_Y25_Yp80",
    "XYY2000_Y400_Yp170",
    "XYY2000_Y400_Yp25",
    "XYY2000_Y400_Yp400",
    "XYY2000_Y400_Yp80",
    "XYY2000_Y80_Yp170",
    "XYY2000_Y80_Yp400",
    "XYY2000_Y80_Yp80",
    "XYY2000_Y170_Yp170",
    "XYY2000_Y170_Yp25",
    "XYY2000_Y170_Yp80",
    "XYY2000_Y25_Yp400",
    "XYY2000_Y25_Yp170",
    "XYY2000_Y80_Yp25",
    "XYY5000_Y170_Yp170",
    "XYY5000_Y170_Yp80",
    "XYY5000_Y25_Yp170",
    "XYY5000_Y25_Yp25",
    "XYY5000_Y25_Yp400",
    "XYY5000_Y25_Yp80",
    "XYY5000_Y400_Yp170",
    "XYY5000_Y400_Yp25",
    "XYY5000_Y400_Yp400",
    "XYY5000_Y80_Yp25",
    "XYY5000_Y80_Yp400",
    "XYY5000_Y170_Yp25",
    "XYY5000_Y170_Yp400",
    "XYY5000_Y400_Yp80",
    "XYY5000_Y80_Yp170",
    "XYY5000_Y80_Yp80",
    "Qstar2000_W170",
    "Qstar2000_W25",
    "Qstar2000_W80",
    "Qstar3000_W170",
    "Qstar3000_W25",
    "Qstar3000_W400",
    "Qstar3000_W80",
    "Wkk2000_R170",
    "Wkk2000_R400",
    "Wkk3000_R170",
    "Wkk5000_R170",
    "Wkk5000_R400",
    "Wp2000_B170_T170",
    "Wp2000_B25_T170",
    "Wp2000_B80_T170",
    "Wp3000_B170_T170",
    "Wp3000_B25_T170",
    "Wp3000_B80_T170",
    "Wp5000_B170_T170",
    "Wp5000_B25_T170",
    "Wp5000_B80_T170",
    "YHH2000_H400",
    "YHH5000_H400",
    "ZTT2000_Tp400",
    "ZTT5000_Tp400"
]
mean_reference = "BKG"
lossEval = LossEval(mean_reference=mean_reference,modelsToEval=models,overwrite=False)
lossEval.evaluateLosses("DATA",chunkSize=100000)
# Out:
# extras =  []
# file 1/40
# 100%|██████████| 71/71 [01:10<00:00,  1.00it/s]
# file 2/40
# 100%|██████████| 71/71 [01:02<00:00,  1.13it/s]
# file 3/40
# 100%|██████████| 71/71 [01:02<00:00,  1.13it/s]
# file 4/40
# 100%|██████████| 71/71 [01:03<00:00,  1.12it/s]
# file 5/40
# 100%|██████████| 71/71 [01:03<00:00,  1.12it/s]
# file 6/40
# 100%|██████████| 71/71 [01:03<00:00,  1.12it/s]
# file 7/40
# 100%|██████████| 71/71 [01:04<00:00,  1.11it/s]
# file 8/40
# 100%|██████████| 71/71 [01:02<00:00,  1.14it/s]
# file 9/40
# 100%|██████████| 71/71 [01:03<00:00,  1.13it/s]
# file 10/40
# 100%|██████████| 71/71 [01:02<00:00,  1.13it/s]
# file 11/40
# 100%|██████████| 71/71 [01:02<00:00,  1.14it/s]
# file 12/40
# 100%|██████████| 71/71 [01:02<00:00,  1.14it/s]
# file 13/40
# 100%|██████████| 71/71 [01:02<00:00,  1.14it/s]
# file 14/40
# 100%|██████████| 71/71 [01:02<00:00,  1.14it/s]
# file 15/40
# 100%|██████████| 71/71 [01:02<00:00,  1.13it/s]
# file 16/40
# ...

# %%
# Evaluate on data SB
lossEval.evaluateLosses("DATA_SB",chunkSize=100000)
# Out:
# ...
# 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]

# %%
# Evaluate on bkg SB
lossEval.evaluateLosses("BKG_SB",chunkSize=100000)
# Out:
# ...
# 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]

# %% [markdown]
# # Triage

# %%
mean_reference = "BKG"
lossEval = LossEval(mean_reference=mean_reference,overwrite=True)
# Out:
# extras =  []

# %%
# Evaluate on signal samples
lossEval.evaluateLosses(bad,chunkSize=100000)
# Out:
# writing mass & systematics
# ...
# 100%|██████████| 26/26 [01:21<00:00,  3.12s/it]

# %%
import os
bad = []
for f in os.listdir('lossEvals'):
    if ".h5" in f:
        with h5py.File('lossEvals/'+f,"r") as fin:
            if "Wp2000_B400_T170" in fin.keys():
                if fin['mjj'].shape[0] < fin['Wp2000_B400_T170'].shape[0]:
                    print(fin['mjj'].shape[0],fin['Wp2000_B400_T170'].shape[0])
                    print(f)
                    bad.append(f.split('.')[0])

# %%
bad
# Out:
# []

# %% [markdown]
# # Loss Norm testing

# %%
from quakSpaceTools import normalizeLosses
files_to_eval = ["Wp3000_B400_T170.h5","XYY3000_Y170_Yp170.h5"]

# %%
normalizeLosses("pca",doBoxCox=True,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 27/27 [00:16<00:00,  1.66it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/3 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#  33%|███▎      | 1/3 [00:18<00:36, 18.13s/it]
# lossEvals/Wp3000_B400_T170.h5
#  67%|██████▋   | 2/3 [00:19<00:07,  7.99s/it]
# lossEvals/XYY3000_Y170_Yp170.h5
# 100%|██████████| 3/3 [00:20<00:00,  6.73s/it]
# Applying box-cox transformed losses & centering background losses on 0
#  26%|██▌       | 7/27 [00:59<02:40,  8.03s/it]/nobackup/users/sambt/anaconda3/envs/quak/lib/python3.7/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /nobackup/users/sambt/anaconda3/envs/quak/lib/python3.7/site-packages/numpy/core/_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
# ...
# 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]

# %%
f1=h5py.File("XYY3000_Y170_Yp170_new.h5","r")
f2=h5py.File("XYY3000_Y170_Yp170_old.h5","r")
f3=h5py.File("lossEvals_pcaDecorr_boxCox/XYY3000_Y170_Yp170.h5","r")
f4=h5py.File("lossEvals_pcaDecorr_boxCox/BKG.h5","r")

# %%
loss='XYY3000_Y170_Yp170'
a1 = f1[loss][()]
a2 = f2[loss][()]
a3 = f3[loss][()]
a4 = f4[loss][()]
h1,bins,_ = plt.hist(a1,bins=50,histtype='step',label='xyy june',density=True)
h2,bins,_ = plt.hist(a2,bins=bins,histtype='step',label='xyy old (pre-unblind)',density=True)
h3,bins,_ = plt.hist(a3,bins=bins,histtype='step',label='xyy re-eval 7/21',density=True)
h4,bins,_ = plt.hist(a4,bins=bins,histtype='step',label='bkg re-eval 7/21',density=True)
plt.xlabel(loss)
plt.legend()
#plt.yscale('log')

# %%
f1.close()
f2.close()
f3.close()
f4.close()

# %% [markdown]
# # Loss norm specific files

# %%
from quakSpaceTools import normalizeLosses
files_to_eval = ["XYY2000_Y25_Yp170.h5"]

# %%
normalizeLosses("pca",doBoxCox=True,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 27/27 [00:37<00:00,  1.39s/it]
# Applying transformations, recording min/max loss values
#   0%|          | 0/2 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#  50%|█████     | 1/2 [00:05<00:05,  5.50s/it]
# lossEvals/XYY2000_Y25_Yp170.h5
# 100%|██████████| 2/2 [00:07<00:00,  3.53s/it]
# Applying box-cox transformed losses & centering background losses on 0
#  26%|██▌       | 7/27 [00:56<02:31,  7.60s/it]/nobackup/users/sambt/anaconda3/envs/quakup/lib/python3.7/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /nobackup/users/sambt/anaconda3/envs/quakup/lib/python3.7/site-packages/numpy/core/_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
# ...
# 100%|██████████| 1/1 [00:01<00:00,  1.71s/it]

# %%
files_to_eval = ["XYY3000_Y400_Yp400_smear5","XYY3000_Y400_Yp400_smear10","XYY3000_Y400_Yp400_smear20",
           "XYY3000_Y400_Yp400_smear30","XYY3000_Y400_Yp400_smear40"]
files_to_eval = [f+".h5" for f in files_to_eval]
normalizeLosses("pca",doBoxCox=True,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 27/27 [00:16<00:00,  1.66it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/6 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#  17%|█▋        | 1/6 [00:07<00:35,  7.11s/it]
# lossEvals/XYY3000_Y400_Yp400_smear5.h5
#  33%|███▎      | 2/6 [00:08<00:14,  3.56s/it]
# lossEvals/XYY3000_Y400_Yp400_smear10.h5
#  50%|█████     | 3/6 [00:09<00:07,  2.42s/it]
# lossEvals/XYY3000_Y400_Yp400_smear20.h5
#  67%|██████▋   | 4/6 [00:10<00:03,  1.89s/it]
# lossEvals/XYY3000_Y400_Yp400_smear30.h5
#  83%|████████▎ | 5/6 [00:11<00:01,  1.60s/it]
# lossEvals/XYY3000_Y400_Yp400_smear40.h5
# 100%|██████████| 6/6 [00:12<00:00,  2.08s/it]
# Applying box-cox transformed losses & centering background losses on 0
#  26%|██▌       | 7/27 [00:58<02:36,  7.83s/it]/nobackup/users/sambt/anaconda3/envs/quakup/lib/python3.7/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# ...

# %% [markdown]
# # Various Loss Normalizations

# %%
from quakSpaceTools import normalizeLosses

# %%
normalizeLosses("pca",doBoxCox=True)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 27/27 [00:32<00:00,  1.20s/it]
# Applying transformations, recording min/max loss values
#   0%|          | 0/85 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/85 [00:27<39:00, 27.86s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/85 [00:29<17:34, 12.71s/it]
# lossEvals/Wp5000_B25_T170.h5
#   4%|▎         | 3/85 [00:30<10:01,  7.33s/it]
# lossEvals/ZTT5000_Tp400.h5
#   5%|▍         | 4/85 [00:32<06:50,  5.06s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/85 [00:33<04:44,  3.55s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/85 [00:34<03:28,  2.65s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/85 [00:37<03:40,  2.82s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/85 [00:38<02:48,  2.19s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  11%|█         | 9/85 [00:39<02:23,  1.88s/it]
# lossEvals/DATA.h5
#  12%|█▏        | 10/85 [01:54<30:44, 24.59s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
# ...

# %%
normalizeLosses("linear",doBoxCox=True)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 37/37 [00:13<00:00,  2.66it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:16<24:18, 16.38s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:18<11:26,  7.80s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:19<06:48,  4.69s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:20<04:53,  3.41s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:21<03:35,  2.53s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:22<02:47,  1.99s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:23<02:29,  1.80s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:24<02:05,  1.53s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:26<02:05,  1.54s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:27<01:56,  1.46s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("pca",doBoxCox=False)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 37/37 [00:24<00:00,  1.53it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:16<25:01, 16.87s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:19<12:05,  8.25s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:20<07:08,  4.93s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:21<05:19,  3.71s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:23<03:55,  2.78s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:24<03:04,  2.19s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:25<02:42,  1.95s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:26<02:20,  1.71s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:28<02:17,  1.70s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:30<02:14,  1.68s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("linear",doBoxCox=False)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 37/37 [00:14<00:00,  2.64it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:15<22:30, 15.17s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:16<10:41,  7.29s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:17<06:22,  4.40s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:19<04:48,  3.36s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:20<03:31,  2.49s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:21<02:45,  1.97s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:23<02:29,  1.81s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:24<02:06,  1.55s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:25<01:58,  1.46s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:26<01:52,  1.41s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("none",doBoxCox=False)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:12<19:07, 12.89s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:14<08:51,  6.04s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:14<05:15,  3.63s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:16<03:52,  2.71s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:16<02:48,  1.98s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:17<02:10,  1.55s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:18<01:53,  1.37s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:19<01:35,  1.17s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:20<01:33,  1.16s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:21<01:37,  1.21s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
#  12%|█▏        | 11/90 [00:22<01:31,  1.16s/it]
# lossEvals/XYY3000_Y25_Yp400.h5
# ...

# %%
normalizeLosses("none",doBoxCox=True)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:16<24:42, 16.66s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:18<11:13,  7.65s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:18<06:30,  4.48s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:20<04:43,  3.30s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:21<03:26,  2.43s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:21<02:35,  1.85s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:23<02:26,  1.76s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:24<01:57,  1.43s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:25<01:53,  1.40s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:26<01:53,  1.42s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
#  12%|█▏        | 11/90 [00:27<01:43,  1.32s/it]
# lossEvals/XYY3000_Y25_Yp400.h5
# ...

# %% [markdown]
# # Evaluate Loss Normalizations on Data!

# %%
from quakSpaceTools import normalizeLosses
files_to_eval = ["DATA.h5"]

# %%
normalizeLosses("pca",doBoxCox=True,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 75/75 [00:49<00:00,  1.52it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/2 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#  50%|█████     | 1/2 [00:32<00:32, 32.59s/it]
# lossEvals/DATA.h5
# 100%|██████████| 2/2 [04:40<00:00, 140.37s/it]
# Applying box-cox transformed losses & centering background losses on 0
#   9%|▉         | 7/75 [01:04<10:01,  8.85s/it]/nobackup/users/sambt/anaconda3/envs/quak/lib/python3.7/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
#  24%|██▍       | 18/75 [02:34<07:48,  8.21s/it]/nobackup/users/sambt/anaconda3/envs/quak/lib/python3.7/site-packages/numpy/core/_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
# ...
# 100%|██████████| 1/1 [01:38<00:00, 98.80s/it]

# %%
normalizeLosses("linear",doBoxCox=True,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 75/75 [00:26<00:00,  2.80it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/2 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#  50%|█████     | 1/2 [00:28<00:28, 28.14s/it]
# lossEvals/DATA.h5
# 100%|██████████| 2/2 [03:45<00:00, 112.66s/it]
# Applying box-cox transformed losses & centering background losses on 0
#   9%|▉         | 7/75 [01:02<10:23,  9.17s/it]/nobackup/users/sambt/anaconda3/envs/quak/lib/python3.7/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
#  24%|██▍       | 18/75 [02:35<08:07,  8.56s/it]/nobackup/users/sambt/anaconda3/envs/quak/lib/python3.7/site-packages/numpy/core/_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
# ...

# %%
normalizeLosses("pca",doBoxCox=False,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 75/75 [00:47<00:00,  1.58it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/2 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#  50%|█████     | 1/2 [00:25<00:25, 25.60s/it]
# lossEvals/DATA.h5
# 100%|██████████| 2/2 [02:45<00:00, 82.76s/it]
# Centering background losses on 0
# ...
# 100%|██████████| 1/1 [00:21<00:00, 21.88s/it]

# %%
normalizeLosses("linear",doBoxCox=False,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 75/75 [00:26<00:00,  2.82it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/2 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#  50%|█████     | 1/2 [00:22<00:22, 22.04s/it]
# lossEvals/DATA.h5
# 100%|██████████| 2/2 [04:09<00:00, 124.73s/it]
# Centering background losses on 0
# ...
# 100%|██████████| 1/1 [00:30<00:00, 30.50s/it]

# %%
normalizeLosses("none",doBoxCox=False,files_to_eval=files_to_eval)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/2 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#  50%|█████     | 1/2 [00:18<00:18, 18.57s/it]
# lossEvals/DATA.h5
# 100%|██████████| 2/2 [03:47<00:00, 113.79s/it]
# Centering background losses on 0
# ...
# 100%|██████████| 1/1 [00:26<00:00, 26.47s/it]

# %%
normalizeLosses("none",doBoxCox=True,files_to_eval=files_to_eval)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/2 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#  50%|█████     | 1/2 [00:23<00:23, 23.74s/it]
# lossEvals/DATA.h5
# 100%|██████████| 2/2 [03:55<00:00, 117.57s/it]
# Applying box-cox transformed losses & centering background losses on 0
#   9%|▉         | 7/75 [01:00<10:12,  9.00s/it]/nobackup/users/sambt/anaconda3/envs/quak/lib/python3.7/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /nobackup/users/sambt/anaconda3/envs/quak/lib/python3.7/site-packages/numpy/core/_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
#  80%|████████  | 60/75 [08:47<02:18,  9.25s/it]/nobackup/users/sambt/anaconda3/envs/quak/lib/python3.7/site-packages/numpy/core/_methods.py:192: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True)
# ...

# %% [markdown]
# # Loss normalizations on signal only

# %%
from quakSpaceTools import normalizeLosses
import os
files_to_eval = [f for f in os.listdir('lossEvals/') if '.h5' in f and 'BKG' not in f and 'DATA' not in f and 'RSG' not in f]

# %%
normalizeLosses("pca",doBoxCox=True,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 75/75 [00:59<00:00,  1.26it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/84 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/84 [01:17<1:47:44, 77.89s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/84 [01:33<56:26, 41.30s/it]
# lossEvals/Wp5000_B25_T170.h5
#   4%|▎         | 3/84 [01:34<31:07, 23.05s/it]
# lossEvals/ZTT5000_Tp400.h5
#   5%|▍         | 4/84 [01:43<23:22, 17.53s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/84 [01:45<15:30, 11.77s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/84 [01:47<10:49,  8.33s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/84 [01:55<10:47,  8.41s/it]
# lossEvals/Qstar2000_W80.h5
#  10%|▉         | 8/84 [01:57<07:51,  6.21s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  11%|█         | 9/84 [02:04<08:01,  6.42s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  12%|█▏        | 10/84 [02:13<08:51,  7.18s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("linear",doBoxCox=True,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 75/75 [00:31<00:00,  2.38it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/84 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/84 [00:34<48:08, 34.80s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/84 [00:37<21:56, 16.05s/it]
# lossEvals/Wp5000_B25_T170.h5
#   4%|▎         | 3/84 [00:39<12:33,  9.30s/it]
# lossEvals/ZTT5000_Tp400.h5
#   5%|▍         | 4/84 [00:41<08:35,  6.45s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/84 [00:42<06:08,  4.66s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/84 [00:44<04:42,  3.63s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/84 [00:46<03:54,  3.04s/it]
# lossEvals/Qstar2000_W80.h5
#  10%|▉         | 8/84 [00:47<03:15,  2.57s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  11%|█         | 9/84 [00:49<02:51,  2.29s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  12%|█▏        | 10/84 [00:51<02:40,  2.17s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("pca",doBoxCox=False,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 75/75 [00:58<00:00,  1.29it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/84 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/84 [01:08<1:34:30, 68.33s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/84 [01:20<47:50, 35.00s/it]
# lossEvals/Wp5000_B25_T170.h5
#   4%|▎         | 3/84 [01:21<26:33, 19.67s/it]
# lossEvals/ZTT5000_Tp400.h5
#   5%|▍         | 4/84 [01:28<19:38, 14.73s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/84 [01:30<13:09, 10.00s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/84 [01:31<09:12,  7.09s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/84 [01:37<08:45,  6.82s/it]
# lossEvals/Qstar2000_W80.h5
#  10%|▉         | 8/84 [01:39<06:29,  5.13s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  11%|█         | 9/84 [01:45<06:44,  5.40s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  12%|█▏        | 10/84 [01:55<08:28,  6.87s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("linear",doBoxCox=False,files_to_eval=files_to_eval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 75/75 [00:32<00:00,  2.31it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/84 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/84 [00:39<54:49, 39.64s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/84 [00:42<24:24, 17.87s/it]
# lossEvals/Wp5000_B25_T170.h5
#   4%|▎         | 3/84 [00:43<14:10, 10.50s/it]
# lossEvals/ZTT5000_Tp400.h5
#   5%|▍         | 4/84 [00:46<09:42,  7.28s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/84 [00:47<06:49,  5.19s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/84 [00:49<05:07,  3.94s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/84 [00:51<04:09,  3.24s/it]
# lossEvals/Qstar2000_W80.h5
#  10%|▉         | 8/84 [00:52<03:22,  2.66s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  11%|█         | 9/84 [00:54<03:09,  2.53s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  12%|█▏        | 10/84 [00:56<02:49,  2.28s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("none",doBoxCox=False,files_to_eval=files_to_eval)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/84 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/84 [00:16<22:28, 16.25s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/84 [00:18<10:49,  7.91s/it]
# lossEvals/Wp5000_B25_T170.h5
#   4%|▎         | 3/84 [00:19<06:25,  4.76s/it]
# lossEvals/ZTT5000_Tp400.h5
#   5%|▍         | 4/84 [00:21<04:49,  3.62s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/84 [00:22<03:33,  2.70s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/84 [00:23<02:51,  2.19s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/84 [00:24<02:31,  1.96s/it]
# lossEvals/Qstar2000_W80.h5
#  10%|▉         | 8/84 [00:26<02:13,  1.76s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  11%|█         | 9/84 [00:27<02:01,  1.62s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  12%|█▏        | 10/84 [00:28<01:52,  1.51s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
#  13%|█▎        | 11/84 [00:30<01:48,  1.48s/it]
# lossEvals/XYY3000_Y25_Yp400.h5
# ...

# %%
normalizeLosses("none",doBoxCox=True,files_to_eval=files_to_eval)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/84 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/84 [00:35<49:21, 35.69s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/84 [00:37<21:43, 15.89s/it]
# lossEvals/Wp5000_B25_T170.h5
#   4%|▎         | 3/84 [00:38<12:18,  9.12s/it]
# lossEvals/ZTT5000_Tp400.h5
#   5%|▍         | 4/84 [00:40<08:20,  6.26s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/84 [00:41<05:50,  4.44s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/84 [00:42<04:15,  3.28s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/84 [00:44<03:30,  2.73s/it]
# lossEvals/Qstar2000_W80.h5
#  10%|▉         | 8/84 [00:45<02:55,  2.31s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  11%|█         | 9/84 [00:48<02:56,  2.35s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  12%|█▏        | 10/84 [00:51<03:05,  2.51s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
#  13%|█▎        | 11/84 [00:53<02:48,  2.31s/it]
# lossEvals/XYY3000_Y25_Yp400.h5
# ...

# %% [markdown]
# # Various Loss Normalizations w/o overwriting

# %%
from quakSpaceTools import normalizeLosses

# %%
normalizeLosses("pca",doBoxCox=True,overwrite=False)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:06<09:14,  6.23s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:07<04:53,  3.33s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:08<03:27,  2.39s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:10<02:54,  2.03s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:11<02:18,  1.63s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:12<01:58,  1.41s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:13<01:53,  1.37s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:14<01:38,  1.20s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:15<01:40,  1.24s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:17<01:43,  1.29s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("linear",doBoxCox=True,overwrite=False)
# Out:
# Fitting PCAs and linear fits
# 0it [00:00, ?it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:00<00:04, 19.05it/s]
# lossEvals/Wp5000_B25_T170.h5
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:00<00:05, 15.37it/s]
# lossEvals/Qstar5000_W80.h5
#   7%|▋         | 6/90 [00:00<00:06, 13.05it/s]
# lossEvals/Qstar5000_W25.h5
# lossEvals/XYY5000_Y400_Yp170.h5
#   9%|▉         | 8/90 [00:00<00:06, 12.58it/s]
# lossEvals/Qstar2000_W80.h5
# lossEvals/XYY5000_Y80_Yp170.h5
#  11%|█         | 10/90 [00:00<00:05, 13.45it/s]
# lossEvals/XYY3000_Y25_Yp25.h5
# lossEvals/XYY5000_Y80_Yp80.h5
#  13%|█▎        | 12/90 [00:00<00:06, 12.44it/s]
# lossEvals/XYY3000_Y25_Yp400.h5
# lossEvals/Wkk5000_R400.h5
# lossEvals/XYY2000_Y25_Yp80.h5
#  18%|█▊        | 16/90 [00:01<00:06, 11.61it/s]
# lossEvals/Wp5000_B400_T170.h5
# lossEvals/Wp3000_B170_T170.h5
# ...

# %%
normalizeLosses("pca",doBoxCox=False,overwrite=False)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 7/7 [00:04<00:00,  1.59it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:01<02:06,  1.42s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:03<02:31,  1.72s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:05<02:36,  1.80s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:07<03:06,  2.17s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:09<02:45,  1.94s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:11<02:32,  1.82s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:13<02:37,  1.90s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:14<02:21,  1.73s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:16<02:25,  1.79s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:18<02:28,  1.86s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("linear",doBoxCox=False,overwrite=False)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 7/7 [00:02<00:00,  2.86it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:01<01:57,  1.32s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:03<02:36,  1.77s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:05<02:43,  1.88s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:07<02:58,  2.08s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:09<02:42,  1.92s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:11<02:31,  1.81s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:13<02:39,  1.93s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:14<02:34,  1.88s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:17<02:40,  1.98s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:19<02:39,  2.00s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("none",doBoxCox=False,overwrite=False)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:01<01:58,  1.33s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:03<02:21,  1.61s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:04<02:27,  1.69s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:06<02:38,  1.84s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:08<02:26,  1.72s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:10<02:27,  1.76s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:12<02:34,  1.86s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:13<02:19,  1.71s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:16<02:33,  1.90s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:18<02:36,  1.95s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
#  12%|█▏        | 11/90 [00:20<02:42,  2.06s/it]
# lossEvals/XYY3000_Y25_Yp400.h5
# ...

# %%
normalizeLosses("none",doBoxCox=True,overwrite=False)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:01<01:53,  1.27s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:03<02:21,  1.60s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:05<02:36,  1.80s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:07<02:51,  2.00s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:09<02:38,  1.86s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:10<02:30,  1.79s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:12<02:35,  1.87s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:14<02:21,  1.73s/it]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:16<02:28,  1.83s/it]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:18<02:30,  1.88s/it]
# lossEvals/XYY5000_Y80_Yp80.h5
#  12%|█▏        | 11/90 [00:20<02:34,  1.95s/it]
# lossEvals/XYY3000_Y25_Yp400.h5
# ...

# %% [markdown]
# # Various Loss Normalizations on specific losses

# %%
from quakSpaceTools import normalizeLosses
toEval = ['XYY3000_Y170_Yp170_v2']

# %%
normalizeLosses("pca",doBoxCox=True,overwrite=False,toEval=toEval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/91 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/91 [00:00<00:32,  2.74it/s]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/91 [00:01<01:28,  1.00it/s]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/91 [00:03<01:36,  1.09s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/91 [00:04<01:45,  1.21s/it]
# lossEvals/XYY3000_Y400_Yp400_smear10.h5
#   5%|▌         | 5/91 [00:05<01:50,  1.29s/it]
# lossEvals/Qstar5000_W80.h5
#   7%|▋         | 6/91 [00:06<01:40,  1.19s/it]
# lossEvals/Qstar5000_W25.h5
#   8%|▊         | 7/91 [00:07<01:35,  1.14s/it]
# lossEvals/XYY3000_Y400_Yp400_smear20.h5
#   9%|▉         | 8/91 [00:08<01:33,  1.13s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#  10%|▉         | 9/91 [00:10<01:38,  1.20s/it]
# lossEvals/Qstar2000_W80.h5
#  11%|█         | 10/91 [00:11<01:41,  1.25s/it]
# ...

# %%
normalizeLosses("linear",doBoxCox=True,overwrite=False,toEval=toEval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 1/1 [00:00<00:00,  2.33it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:00<00:22,  3.88it/s]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:00<00:35,  2.45it/s]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:01<00:45,  1.90it/s]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:02<00:46,  1.84it/s]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:02<00:40,  2.12it/s]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:02<00:40,  2.08it/s]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:03<00:41,  1.98it/s]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:03<00:39,  2.06it/s]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:04<00:34,  2.35it/s]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:04<00:43,  1.85it/s]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("pca",doBoxCox=False,overwrite=False,toEval=toEval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:07<11:22,  7.66s/it]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:09<06:15,  4.27s/it]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:09<03:37,  2.50s/it]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:11<02:49,  1.97s/it]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:11<01:57,  1.38s/it]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:11<01:26,  1.03s/it]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:12<01:23,  1.00s/it]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:13<01:06,  1.24it/s]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:14<01:08,  1.18it/s]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:15<01:16,  1.05it/s]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("linear",doBoxCox=False,overwrite=False,toEval=toEval)
# Out:
# Fitting PCAs and linear fits
# 100%|██████████| 1/1 [00:00<00:00,  2.75it/s]
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   1%|          | 1/90 [00:00<00:20,  4.37it/s]
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:00<00:24,  3.56it/s]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:00<00:26,  3.27it/s]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:01<00:27,  3.18it/s]
# lossEvals/Qstar5000_W80.h5
#   6%|▌         | 5/90 [00:01<00:27,  3.08it/s]
# lossEvals/Qstar5000_W25.h5
#   7%|▋         | 6/90 [00:01<00:29,  2.82it/s]
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:02<00:28,  2.91it/s]
# lossEvals/Qstar2000_W80.h5
#   9%|▉         | 8/90 [00:02<00:25,  3.21it/s]
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:02<00:25,  3.17it/s]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:03<00:25,  3.18it/s]
# lossEvals/XYY5000_Y80_Yp80.h5
# ...

# %%
normalizeLosses("none",doBoxCox=False,overwrite=False,toEval=toEval)
# Out:
# Applying transformations, recording min/max loss values
#   0%|          | 0/90 [00:00<?, ?it/s]
# lossEvals/BKG.h5
#   2%|▏         | 2/90 [00:00<00:17,  5.01it/s]
# lossEvals/YHH3000_H400.h5
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:00<00:17,  4.90it/s]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:00<00:19,  4.52it/s]
# lossEvals/Qstar5000_W80.h5
#   7%|▋         | 6/90 [00:01<00:17,  4.77it/s]
# lossEvals/Qstar5000_W25.h5
# lossEvals/XYY5000_Y400_Yp170.h5
#   8%|▊         | 7/90 [00:01<00:17,  4.74it/s]
# lossEvals/Qstar2000_W80.h5
#  10%|█         | 9/90 [00:01<00:18,  4.41it/s]
# lossEvals/XYY5000_Y80_Yp170.h5
# lossEvals/XYY3000_Y25_Yp25.h5
#  12%|█▏        | 11/90 [00:02<00:18,  4.38it/s]
# lossEvals/XYY5000_Y80_Yp80.h5
# lossEvals/XYY3000_Y25_Yp400.h5
#  14%|█▍        | 13/90 [00:02<00:17,  4.35it/s]
# lossEvals/Wkk5000_R400.h5
# lossEvals/XYY2000_Y25_Yp80.h5
#  17%|█▋        | 15/90 [00:03<00:15,  4.70it/s]
# lossEvals/Wp5000_B400_T170.h5
# ...

# %%
normalizeLosses("none",doBoxCox=True,overwrite=False,toEval=toEval)
# Out:
# Applying transformations, recording min/max loss values
#   1%|          | 1/90 [00:00<00:17,  5.22it/s]
# lossEvals/BKG.h5
# lossEvals/YHH3000_H400.h5
#   2%|▏         | 2/90 [00:00<00:15,  5.83it/s]
# lossEvals/Wp5000_B25_T170.h5
#   3%|▎         | 3/90 [00:00<00:17,  4.89it/s]
# lossEvals/ZTT5000_Tp400.h5
#   4%|▍         | 4/90 [00:00<00:18,  4.54it/s]
# lossEvals/Qstar5000_W80.h5
#   7%|▋         | 6/90 [00:01<00:18,  4.53it/s]
# lossEvals/Qstar5000_W25.h5
# lossEvals/XYY5000_Y400_Yp170.h5
#   9%|▉         | 8/90 [00:01<00:16,  4.89it/s]
# lossEvals/Qstar2000_W80.h5
# lossEvals/XYY5000_Y80_Yp170.h5
#  10%|█         | 9/90 [00:01<00:16,  4.77it/s]
# lossEvals/XYY3000_Y25_Yp25.h5
#  11%|█         | 10/90 [00:02<00:18,  4.30it/s]
# lossEvals/XYY5000_Y80_Yp80.h5
#  12%|█▏        | 11/90 [00:02<00:19,  4.04it/s]
# lossEvals/XYY3000_Y25_Yp400.h5
#  13%|█▎        | 12/90 [00:02<00:18,  4.22it/s]
# lossEvals/Wkk5000_R400.h5
#  14%|█▍        | 13/90 [00:02<00:18,  4.25it/s]
# ...
