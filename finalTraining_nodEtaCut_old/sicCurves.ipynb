# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from quakSpaceTools import sic_curve
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # XYY SIC curves - SumProb

# %%
# pca + boxcox + decorr
bkg_axis = "BKG_mjjFlat"
sig_axes = ["M80-80","M80-170","M80-400","M170-170","M170-400","M400-400"]
reduction = "SumProb"
sample = "XYY3000_Y170_Yp170"
sic_curve(bkg_axis,sig_axes,"MassBin_no25",reduction,sample,decorr=True,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox
bkg_axis = "BKG_mjjFlat"
sig_axes = ["M80-80","M80-170","M80-400","M170-170","M170-400","M400-400"]
reduction = "SumProb"
sample = "XYY3000_Y170_Yp170"
sic_curve(bkg_axis,sig_axes,"MassBin_no25",reduction,sample,decorr=False,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox + decorr
bkg_axis = "BKG_mjjFlat"
sig_axes = ["XYY3000_Y170_Yp170","Wp3000_B400_T170","RSG3000","Qstar2000_W400","Wkk3000_R400"]
reduction = "SumProb"
sample = "XYY3000_Y170_Yp170"
sic_curve(bkg_axis,sig_axes,"fiveSigs",reduction,sample,decorr=True,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox
bkg_axis = "BKG_mjjFlat"
sig_axes = ["XYY3000_Y170_Yp170","Wp3000_B400_T170","RSG3000","Qstar2000_W400","Wkk3000_R400"]
reduction = "SumProb"
sample = "XYY3000_Y170_Yp170"
sic_curve(bkg_axis,sig_axes,"fiveSigs",reduction,sample,decorr=False,base="lossEvals_pcaDecorr_boxCox")

# %% [markdown]
# # Wprime SIC curves - SumProb

# %%
# pca + boxcox + decorr
bkg_axis = "BKG_mjjFlat"
sig_axes = ["M80-80","M80-170","M80-400","M170-170","M170-400","M400-400"]
reduction = "SumProb"
sample = "Wp3000_B400_T170"
sic_curve(bkg_axis,sig_axes,"MassBin_no25",reduction,sample,decorr=True,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox
bkg_axis = "BKG_mjjFlat"
sig_axes = ["M80-80","M80-170","M80-400","M170-170","M170-400","M400-400"]
reduction = "SumProb"
sample = "Wp3000_B400_T170"
sic_curve(bkg_axis,sig_axes,"MassBin_no25",reduction,sample,decorr=False,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox + decorr
bkg_axis = "BKG_mjjFlat"
sig_axes = ["XYY3000_Y170_Yp170","Wp3000_B400_T170","RSG3000","Qstar2000_W400","Wkk3000_R400"]
reduction = "SumProb"
sample = "Wp3000_B400_T170"
sic_curve(bkg_axis,sig_axes,"fiveSigs",reduction,sample,decorr=True,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox
bkg_axis = "BKG_mjjFlat"
sig_axes = ["XYY3000_Y170_Yp170","Wp3000_B400_T170","RSG3000","Qstar2000_W400","Wkk3000_R400"]
reduction = "SumProb"
sample = "Wp3000_B400_T170"
sic_curve(bkg_axis,sig_axes,"fiveSigs",reduction,sample,decorr=False,base="lossEvals_pcaDecorr_boxCox")

# %% [markdown]
# # XYY - signed L5

# %%
# pca + boxcox + decorr
bkg_axis = "BKG_mjjFlat"
sig_axes = ["M80-80","M80-170","M80-400","M170-170","M170-400","M400-400"]
reduction = "signedL5"
sample = "XYY3000_Y170_Yp170"
sic_curve(bkg_axis,sig_axes,"MassBin_no25",reduction,sample,decorr=True,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox
bkg_axis = "BKG_mjjFlat"
sig_axes = ["M80-80","M80-170","M80-400","M170-170","M170-400","M400-400"]
reduction = "signedL5"
sample = "XYY3000_Y170_Yp170"
sic_curve(bkg_axis,sig_axes,"MassBin_no25",reduction,sample,decorr=False,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox + decorr
bkg_axis = "BKG_mjjFlat"
sig_axes = ["XYY3000_Y170_Yp170","Wp3000_B400_T170","RSG3000","Qstar2000_W400","Wkk3000_R400"]
reduction = "signedL5"
sample = "XYY3000_Y170_Yp170"
sic_curve(bkg_axis,sig_axes,"fiveSigs",reduction,sample,decorr=True,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox
bkg_axis = "BKG_mjjFlat"
sig_axes = ["XYY3000_Y170_Yp170","Wp3000_B400_T170","RSG3000","Qstar2000_W400","Wkk3000_R400"]
reduction = "signedL5"
sample = "XYY3000_Y170_Yp170"
sic_curve(bkg_axis,sig_axes,"fiveSigs",reduction,sample,decorr=False,base="lossEvals_pcaDecorr_boxCox")

# %% [markdown]
# # Wprime - signed L5

# %%
# pca + boxcox + decorr
bkg_axis = "BKG_mjjFlat"
sig_axes = ["M80-80","M80-170","M80-400","M170-170","M170-400","M400-400"]
reduction = "signedL5"
sample = "Wp3000_B400_T170"
sic_curve(bkg_axis,sig_axes,"MassBin_no25",reduction,sample,decorr=True,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox
bkg_axis = "BKG_mjjFlat"
sig_axes = ["M80-80","M80-170","M80-400","M170-170","M170-400","M400-400"]
reduction = "signedL5"
sample = "Wp3000_B400_T170"
sic_curve(bkg_axis,sig_axes,"MassBin_no25",reduction,sample,decorr=False,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox + decorr
bkg_axis = "BKG_mjjFlat"
sig_axes = ["XYY3000_Y170_Yp170","Wp3000_B400_T170","RSG3000","Qstar2000_W400","Wkk3000_R400"]
reduction = "signedL5"
sample = "Wp3000_B400_T170"
sic_curve(bkg_axis,sig_axes,"fiveSigs",reduction,sample,decorr=True,base="lossEvals_pcaDecorr_boxCox")

# %%
# pca + boxcox
bkg_axis = "BKG_mjjFlat"
sig_axes = ["XYY3000_Y170_Yp170","Wp3000_B400_T170","RSG3000","Qstar2000_W400","Wkk3000_R400"]
reduction = "signedL5"
sample = "Wp3000_B400_T170"
sic_curve(bkg_axis,sig_axes,"fiveSigs",reduction,sample,decorr=False,base="lossEvals_pcaDecorr_boxCox")
